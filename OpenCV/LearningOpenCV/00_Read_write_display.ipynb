# %% [markdown]
# Imports

# %%
import cv2

# %% [markdown]
# Read image

# %%
path = 'Peacock.jpg' # Path to image
image = cv2.imread(path)
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# Show image

# %%
while True:
    cv2.imshow('Peacock',image)
    if cv2.waitKey(0) == ord('q') or cv2.waitKey(0) != -1:
        break
cv2.destroyAllWindows()
# Press 'q' to close the image
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /home/arjun/Documents/GitHub/Learning-Things/OpenCV/LearningOpenCV/00_Read_write_display.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/home/arjun/Documents/GitHub/Learning-Things/OpenCV/LearningOpenCV/00_Read_write_display.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> while True:
# ----> <a href='vscode-notebook-cell:/home/arjun/Documents/GitHub/Learning-Things/OpenCV/LearningOpenCV/00_Read_write_display.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     cv2.imshow('Peacock',image)
#       <a href='vscode-notebook-cell:/home/arjun/Documents/GitHub/Learning-Things/OpenCV/LearningOpenCV/00_Read_write_display.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     if cv2.waitKey(0) == ord('q') or cv2.waitKey(0) != -1:
# ...

# %%
print(image.shape)
# Out:
# (900, 1200, 3)

# %% [markdown]
# Peeking into image

# %%
# print(image)
print(type(image))
print(image.shape)
print(image.dtype)
# Out:
# <class 'numpy.ndarray'>
# (900, 1200, 3)
# uint8

# %% [markdown]
# Alternative: Using matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(image)              # we could also have used np array of the image in imshow
plt.show()
# Here image is in a different color format[BGR]. We can change it to RGB to view the original image. We'll see how we do that in next notebook

# %% [markdown]
# Saving as .png

# %%
cv2.imwrite('Pcock.png', image)
# Out:
# True
