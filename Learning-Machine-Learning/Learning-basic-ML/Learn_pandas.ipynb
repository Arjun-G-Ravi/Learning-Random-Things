# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv',index_col=0)
print(df['LotArea'])
# Out:
# Id
# 1        8450
# 2        9600
# 3       11250
# 4        9550
# 5       14260
#         ...
# 1456     7917
# 1457    13175
# 1458     9042
# 1459     9717
# 1460     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
print(df.loc[:,'LotArea'])
df
# Out:
# Id
# 1        8450
# 2        9600
# 3       11250
# 4        9550
# 5       14260
#         ...
# 1456     7917
# 1457    13175
# 1458     9042
# 1459     9717
# 1460     9937
# Name: LotArea, Length: 1460, dtype: int64
#       MSSubClass MSZoning  LotFrontage  LotArea  Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450    2920   NaN      Reg
# 2             20       RL         80.0     9600    2918   NaN      Reg
# 3             60       RL         68.0    11250    2916   NaN      IR1
# 4             70       RL         60.0     9550    2914   NaN      IR1
# 5             60       RL         84.0    14260    2912   NaN      IR1
# ...          ...      ...          ...      ...     ...   ...      ...
# 1456          60       RL         62.0     7917      10   NaN      Reg
# 1457          20       RL         85.0    13175       8   NaN      Reg
# 1458          70       RL         66.0     9042       6   NaN      Reg
# ...

# %%
df.loc[(df["PoolArea"]!=0) | (df['MSSubClass']!=60)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.loc[df['PoolQC'].isnull()]
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
print(df.loc(df[:,4]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11060/4103627226.py in <module>
# ----> 1 print(df.loc(df[:,4]))
#
# c:\Users\Home\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\Home\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea  Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450    2920   NaN      Reg
# 2             20       RL         80.0     9600    2918   NaN      Reg
# 3             60       RL         68.0    11250    2916   NaN      IR1
# 4             70       RL         60.0     9550    2914   NaN      IR1
# 5             60       RL         84.0    14260    2912   NaN      IR1
# ...          ...      ...          ...      ...     ...   ...      ...
# 1456          60       RL         62.0     7917      10   NaN      Reg
# 1457          20       RL         85.0    13175       8   NaN      Reg
# 1458          70       RL         66.0     9042       6   NaN      Reg
# 1459          20       RL         68.0     9717       4   NaN      Reg
# 1460          20       RL         75.0     9937       2   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# Testing

# %%
X=pd.DataFrame({"Tom":['Fast','Strong'], 'Jerry':["Faster","Clever"]},index=['Speed','fd'])
X
# Out:
#           Tom   Jerry
# Speed    Fast  Faster
# fd     Strong  Clever
